# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 
import scipy.stats as ss
from scipy.stats import norm
import tensorflow as tf 
from tensorflow.keras import layers
import random
from collections import deque
# Out:
# /Users/mcbookairdebat/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
S0,r,sigma,K,T,dt,num_paths,k=100.0, 0.01, 0.2,100.0, 1.0, 1/252, 10000,0

# %%
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %%
def generate_black_scholes_paths(S0=S0, r=r, sigma=sigma, T=T, dt=dt, num_paths=num_paths):
    """
    Generate simulated stock price paths using Black-Scholes model.
    
    :param S0:       Initial stock price
    :param r:        Risk-free rate
    :param sigma:    Volatility
    :param T:        Time horizon (in years)
    :param dt:       Time step (in years)
    :param num_paths: Number of simulated paths
    :return:         Array of shape (num_paths, num_time_steps + 1)
                     containing simulated stock paths
    """
    # Number of time steps
    num_steps = int(T / dt)
    
    # Pre-allocate the array for paths
    # We'll store the entire evolution, so shape is (num_paths, num_steps + 1)
    paths = np.zeros(( num_steps + 1))
    
    # Set initial prices
    paths[0] = S0
    
    # Precompute constants for the Euler-Maruyama update
    # Using log-Euler approach: S_{t+dt} = S_t * exp((r - 0.5 sigma^2) dt + sigma sqrt(dt) * Z)
    drift = (r - 0.5 * sigma ** 2) * dt
    diffusion = sigma * np.sqrt(dt)
    
    # Simulate paths
    for t in range(num_steps):
        # Draw random samples from the standard normal distribution
        Z = np.random.normal(0, 1, num_paths)
        # Update in log-space
        paths[t+1] = paths[t] * np.exp(drift + diffusion * Z)
    
    return paths

# %%
def call_option_price(S, K, r, sigma, tau):
    d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * tau) / (sigma * np.sqrt(tau))
    d2 = d1 - sigma * np.sqrt(tau)
    return S * norm.cdf(d1) - K * np.exp(-r * tau) * norm.cdf(d2)

# %%
class HedgingEnv:
    def __init__(self, initial_stock_price=100, strike_price=100, maturity=1, volatility=0.2, risk_free_rate=0.01, time_steps=252):
        self.initial_stock_price = initial_stock_price
        self.strike_price = strike_price
        self.maturity = maturity
        self.volatility = volatility
        self.risk_free_rate = risk_free_rate
        self.time_steps = time_steps

        self.dt = maturity / time_steps
        self.current_step = 0

        self.stock_paths = None
        self.hedge_position = 0  # H (action to find)
        self.call_option_value = 0

        self.state_space = 3  # [time to maturity, current stock price, current hedge position]
        self.action_space = 100  # Discrete actions: fractions of the stock [-1, -0.9, ..., 0.9, 1]
        self.actions = np.linspace(0, 1, self.action_space)  # Fractions of stock to hold plutot prendre l'action achat ou vente donc -1 et 1 

    def reset(self):
        self.current_step = 0
        self.stock_paths = generate_black_scholes_paths(self.initial_stock_price, self.risk_free_rate, self.volatility, self.maturity, self.dt,1)
        self.hedge_position = 0
        time_to_maturity = self.maturity - self.current_step * self.dt
        current_stock_price = self.stock_paths[self.current_step]
        self.call_option_value = call_option_price(self.stock_paths[self.current_step],self.strike_price,self.risk_free_rate,self.volatility,self.maturity)
        return np.array([time_to_maturity, current_stock_price, self.hedge_position])

    def step(self, action_index):
        action = self.actions[action_index]  # Convert discrete action index to fraction

        # Update time and state
        self.current_step += 1
        time_to_maturity = self.maturity - self.current_step * self.dt
        current_stock_price = self.stock_paths[self.current_step]
        next_call_option_value = call_option_price(current_stock_price,self.strike_price,self.risk_free_rate,self.volatility, time_to_maturity)
        # Calculate reward based on the provided formula
        # Check if the episode is done
        #done = (self.current_step == self.time_steps) 
        reward = (next_call_option_value - self.call_option_value) + (current_stock_price - self.stock_paths[self.current_step - 1]) * self.hedge_position - 0.025 * abs(current_stock_price * (action - self.hedge_position))
        #if done:
            #reward = -np.max(current_stock_price - self.strike_price,0)
        #else: 
            #reward = current_stock_price * (action - self.hedge_position) - 0.025 * abs(current_stock_price * (action - self.hedge_position))

        # Update hedge position
        self.hedge_position = action
        self.call_option_value = next_call_option_value

        # Check if the episode is done
        done = self.current_step >= self.time_steps - 1

        # State is [time to maturity, current stock price, current hedge position]
        state = np.array([time_to_maturity, current_stock_price, self.hedge_position,])

        return state, reward, done

# %%
# Define Replay Buffer
class ReplayBuffer:
    def __init__(self, buffer_size=2000):
        self.buffer = deque(maxlen=buffer_size)

    def add(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

    def size(self):
        return len(self.buffer)

# %%
# Define Q-Network
class QNetwork(tf.keras.Model):
    def __init__(self, state_dim, action_dim, hidden_units=128):
        super(QNetwork, self).__init__()
        #self.dense = tf.keras.layers.Input(shape=state_dim)
        self.dense1 = tf.keras.layers.Dense(hidden_units, activation='relu')
        self.dense2 = tf.keras.layers.Dense(hidden_units, activation='relu')
        self.dense3 = tf.keras.layers.Dense(hidden_units, activation='relu')
        self.output_layer = tf.keras.layers.Dense(action_dim, activation='linear')

    def call(self, state):
        x = self.dense1(state)
        x = self.dense2(x)
        x= self.dense3(x)
        q_values = self.output_layer(x)
        return q_values

# %%
# Define Deep Q-Learning Agent with Two Q-Networks
class DeepQLearningAgent:
    def __init__(self, state_dim, action_dim, learning_rate=0.001, gamma=1.0, epsilon=1.0, epsilon_decay=0.99, min_epsilon=0.05, c=0.0):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.min_epsilon = min_epsilon
        self.c = c

        self.q1_network = QNetwork(state_dim, action_dim)
        self.q2_network = QNetwork(state_dim, action_dim)
        self.target_q1_network = QNetwork(state_dim, action_dim)
        self.target_q2_network = QNetwork(state_dim, action_dim)

        self.q1_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
        self.q2_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

        self.update_target_networks()

    def update_target_networks(self):
        self.target_q1_network.set_weights(self.q1_network.get_weights())
        self.target_q2_network.set_weights(self.q2_network.get_weights())

    def get_action(self, state):
        if np.random.rand() < self.epsilon:
            return np.random.randint(0, self.action_dim)
        state = np.expand_dims(state, axis=0).astype(np.float32)
        q1_values = self.q1_network(state)
        return np.argmax(q1_values.numpy())

    def train(self, replay_buffer, batch_size=32):
        if replay_buffer.size() < batch_size:
            return

        # Sample from replay buffer
        minibatch = replay_buffer.sample(batch_size)
        states, actions, rewards, next_states, dones = zip(*minibatch)

        states = np.array(states, dtype=np.float32)
        actions = np.array(actions, dtype=np.int32)
        rewards = np.array(rewards, dtype=np.float32)
        next_states = np.array(next_states, dtype=np.float32)
        dones = np.array(dones, dtype=np.float32)

        # Compute target Q-values for Q1 and Q2
        next_q1_values = self.target_q1_network(next_states)
        next_q2_values = self.target_q2_network(next_states)
        max_next_q1_values = np.max(next_q1_values.numpy(), axis=1)
        max_next_q2_values = np.max(next_q2_values.numpy(), axis=1)
        target_q1_values = rewards + self.gamma * max_next_q1_values *(1-dones)
        target_q2_values = rewards ** 2 + (self.gamma)**2 * max_next_q2_values*(1-dones) + 2*self.gamma*rewards*max_next_q2_values*(1-dones)

        # Update Q1 Network
        with tf.GradientTape() as tape:
            q1_values = self.q1_network(states)
            indices = np.arange(batch_size)
            selected_q1_values = tf.reduce_sum(q1_values * tf.one_hot(actions, self.action_dim), axis=1)
            q1_loss = tf.reduce_mean(tf.square(target_q1_values - selected_q1_values))

        q1_grads = tape.gradient(q1_loss, self.q1_network.trainable_variables)
        self.q1_optimizer.apply_gradients(zip(q1_grads, self.q1_network.trainable_variables))

        # Update Q2 Network
        with tf.GradientTape() as tape:
            q2_values = self.q2_network(states)
            selected_q2_values = tf.reduce_sum(q2_values * tf.one_hot(actions, self.action_dim), axis=1)
            q2_loss = tf.reduce_mean(tf.square(target_q2_values - selected_q2_values))

        q2_grads = tape.gradient(q2_loss, self.q2_network.trainable_variables)
        self.q2_optimizer.apply_gradients(zip(q2_grads, self.q2_network.trainable_variables))

        # Decay epsilon
        self.epsilon = max(self.min_epsilon, self.epsilon * self.epsilon_decay)

    def compute_y_objective(self, state, action):
        state = np.expand_dims(state, axis=0).astype(np.float32)
        q1_value = self.q1_network(state).numpy()[0, action]
        q2_value = self.q2_network(state).numpy()[0, action]
        return q1_value + self.c * np.sqrt(q2_value - q1_value ** 2)

# %%
# Training Loop
def train_deep_q_learning(env, agent, replay_buffer, episodes=600, batch_size=32, target_update_freq=10):
    rewards =[]
    functions =[]
    for episode in range(episodes):
        state = env.reset()
        total_reward = 0
        done = False
        
        
        while not done:
            action = agent.get_action(state)
            next_state, reward, done = env.step(action)
            #print(next_state, reward, done)
            replay_buffer.add(state, action, reward, next_state, done)
            agent.train(replay_buffer, batch_size)
            state = next_state
            total_reward += reward

        if episode % target_update_freq == 0:
            agent.update_target_networks()
        rewards.append(total_reward)
        y_objective = agent.compute_y_objective(state, action)
        functions.append(y_objective)
        print(f"Episode {episode}, Total Reward: {total_reward}, Epsilon: {agent.epsilon:.2f}, Y(0): {y_objective:.2f}")
    return rewards,functions

# %%
# Main
if __name__ == "__main__":
    env = HedgingEnv()
    state_dim = env.state_space
    action_dim = env.action_space
    agent = DeepQLearningAgent(state_dim, action_dim)
    replay_buffer = ReplayBuffer(buffer_size=2000)
    rewards,fucntions = train_deep_q_learning(env, agent, replay_buffer)
# Out:
# /var/folders/lc/t3q2r39x05ndfqz7hm78wmkc0000gn/T/ipykernel_95037/152808958.py:34: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   paths[t+1] = paths[t] * np.exp(drift + diffusion * Z)
# /var/folders/lc/t3q2r39x05ndfqz7hm78wmkc0000gn/T/ipykernel_95037/2234719536.py:81: RuntimeWarning: invalid value encountered in sqrt
#   return q1_value + self.c * np.sqrt(q2_value - q1_value ** 2)
# Episode 0, Total Reward: -126.86594265756146, Epsilon: 0.11, Y(0): nan
# Episode 1, Total Reward: -55.418415903330406, Epsilon: 0.05, Y(0): nan
# Episode 2, Total Reward: -30.601578543365743, Epsilon: 0.05, Y(0): nan
# Episode 3, Total Reward: -56.98510060076451, Epsilon: 0.05, Y(0): nan
# Episode 4, Total Reward: -36.238018645324416, Epsilon: 0.05, Y(0): nan
# Episode 5, Total Reward: -40.84189617789689, Epsilon: 0.05, Y(0): nan
# Episode 6, Total Reward: -42.469990548123086, Epsilon: 0.05, Y(0): nan
# Episode 7, Total Reward: -33.15120549818805, Epsilon: 0.05, Y(0): nan
# Episode 8, Total Reward: -18.599897701963258, Epsilon: 0.05, Y(0): nan
# Episode 9, Total Reward: -22.291767858654886, Epsilon: 0.05, Y(0): nan
# Episode 10, Total Reward: -47.30857025632114, Epsilon: 0.05, Y(0): nan
# Episode 11, Total Reward: -65.49973078211133, Epsilon: 0.05, Y(0): nan
# Episode 12, Total Reward: -50.89807182943108, Epsilon: 0.05, Y(0): nan
# Episode 13, Total Reward: -61.6317539541886, Epsilon: 0.05, Y(0): nan
# Episode 14, Total Reward: -47.22551072311932, Epsilon: 0.05, Y(0): nan
# Episode 15, Total Reward: -47.70674118715087, Epsilon: 0.05, Y(0): nan
# Episode 16, Total Reward: -43.037627863056464, Epsilon: 0.05, Y(0): nan
# Episode 17, Total Reward: -48.79870530562247, Epsilon: 0.05, Y(0): nan
# Episode 18, Total Reward: -49.79855470712142, Epsilon: 0.05, Y(0): nan
# Episode 19, Total Reward: 7.046304397009646, Epsilon: 0.05, Y(0): nan
# Episode 20, Total Reward: -44.12795312365538, Epsilon: 0.05, Y(0): nan
# Episode 21, Total Reward: -57.5679119772313, Epsilon: 0.05, Y(0): nan
# Episode 22, Total Reward: -35.237549950751266, Epsilon: 0.05, Y(0): nan
# Episode 23, Total Reward: -46.973923449785744, Epsilon: 0.05, Y(0): nan
# Episode 24, Total Reward: -52.279710382534056, Epsilon: 0.05, Y(0): nan
# Episode 25, Total Reward: 16.85139400626383, Epsilon: 0.05, Y(0): nan
# Episode 26, Total Reward: -55.02458908132523, Epsilon: 0.05, Y(0): nan
# Episode 27, Total Reward: -59.90419133958022, Epsilon: 0.05, Y(0): nan
# Episode 28, Total Reward: -28.8653576704307, Epsilon: 0.05, Y(0): nan
# Episode 29, Total Reward: -56.53724598483251, Epsilon: 0.05, Y(0): nan
# Episode 30, Total Reward: -8.73044909382983, Epsilon: 0.05, Y(0): nan
# Episode 31, Total Reward: -24.2782551385452, Epsilon: 0.05, Y(0): nan
# Episode 32, Total Reward: -56.27160594957667, Epsilon: 0.05, Y(0): nan
# Episode 33, Total Reward: -3.068039650654545, Epsilon: 0.05, Y(0): nan
# Episode 34, Total Reward: 24.18889139289531, Epsilon: 0.05, Y(0): nan
# Episode 35, Total Reward: -9.260710787454293, Epsilon: 0.05, Y(0): nan
# Episode 36, Total Reward: -55.020793232768966, Epsilon: 0.05, Y(0): nan
# Episode 37, Total Reward: -64.056001003941, Epsilon: 0.05, Y(0): nan
# Episode 38, Total Reward: -32.947455338299974, Epsilon: 0.05, Y(0): nan
# Episode 39, Total Reward: -55.67192183498022, Epsilon: 0.05, Y(0): nan
# Episode 40, Total Reward: -39.75985659274107, Epsilon: 0.05, Y(0): nan
# Episode 41, Total Reward: -59.03004242877371, Epsilon: 0.05, Y(0): nan
# Episode 42, Total Reward: -56.87404863875006, Epsilon: 0.05, Y(0): nan
# Episode 43, Total Reward: -36.74615763932218, Epsilon: 0.05, Y(0): nan
# Episode 44, Total Reward: -71.6552013120253, Epsilon: 0.05, Y(0): nan
# Episode 45, Total Reward: -16.655209510700146, Epsilon: 0.05, Y(0): nan
# Episode 46, Total Reward: -42.28191710650789, Epsilon: 0.05, Y(0): nan
# Episode 47, Total Reward: -3.7141548441630103, Epsilon: 0.05, Y(0): nan
# Episode 48, Total Reward: -48.726173353095255, Epsilon: 0.05, Y(0): nan
# Episode 49, Total Reward: -46.09184719153678, Epsilon: 0.05, Y(0): nan
# Episode 50, Total Reward: -5.995636899447601, Epsilon: 0.05, Y(0): nan
# Episode 51, Total Reward: -22.97099012282424, Epsilon: 0.05, Y(0): nan
# Episode 52, Total Reward: -52.11237117231483, Epsilon: 0.05, Y(0): nan
# Episode 53, Total Reward: -72.1264954604151, Epsilon: 0.05, Y(0): nan
# Episode 54, Total Reward: -9.747533414047018, Epsilon: 0.05, Y(0): nan
# Episode 55, Total Reward: -54.55047979997304, Epsilon: 0.05, Y(0): 14.09
# Episode 56, Total Reward: -46.03869267861923, Epsilon: 0.05, Y(0): nan
# Episode 57, Total Reward: -59.33020948269411, Epsilon: 0.05, Y(0): 14.55
# Episode 58, Total Reward: -44.19181148549834, Epsilon: 0.05, Y(0): nan
# Episode 59, Total Reward: -55.02899198319062, Epsilon: 0.05, Y(0): nan
# Episode 60, Total Reward: -31.242503065980266, Epsilon: 0.05, Y(0): nan
# Episode 61, Total Reward: -62.03248254303684, Epsilon: 0.05, Y(0): nan
# Episode 62, Total Reward: -15.004685316048171, Epsilon: 0.05, Y(0): nan
# Episode 63, Total Reward: -49.94551515518131, Epsilon: 0.05, Y(0): 14.92
# Episode 64, Total Reward: -27.748824609910713, Epsilon: 0.05, Y(0): nan
# Episode 65, Total Reward: -45.38070697578996, Epsilon: 0.05, Y(0): nan
# Episode 66, Total Reward: -51.682867717112664, Epsilon: 0.05, Y(0): nan
# Episode 67, Total Reward: -49.23274829633466, Epsilon: 0.05, Y(0): nan
# Episode 68, Total Reward: -0.3258039278834701, Epsilon: 0.05, Y(0): nan
# Episode 69, Total Reward: -29.79631383965585, Epsilon: 0.05, Y(0): nan
# Episode 70, Total Reward: -9.366098034944049, Epsilon: 0.05, Y(0): nan
# Episode 71, Total Reward: -62.48098864427142, Epsilon: 0.05, Y(0): nan
# Episode 72, Total Reward: -51.04018879705101, Epsilon: 0.05, Y(0): 18.03
# Episode 73, Total Reward: -57.00774931267172, Epsilon: 0.05, Y(0): nan
# Episode 74, Total Reward: -44.6327100646972, Epsilon: 0.05, Y(0): nan
# Episode 75, Total Reward: -50.17370124039198, Epsilon: 0.05, Y(0): nan
# Episode 76, Total Reward: -45.411542308618415, Epsilon: 0.05, Y(0): 16.27
# Episode 77, Total Reward: -48.63979424836335, Epsilon: 0.05, Y(0): nan
# Episode 78, Total Reward: -48.27193351600933, Epsilon: 0.05, Y(0): nan
# Episode 79, Total Reward: -43.49054580831601, Epsilon: 0.05, Y(0): 17.39
# Episode 80, Total Reward: -32.90172159062669, Epsilon: 0.05, Y(0): 19.35
# Episode 81, Total Reward: -59.59838049351078, Epsilon: 0.05, Y(0): nan
# Episode 82, Total Reward: -47.32336843544686, Epsilon: 0.05, Y(0): nan
# Episode 83, Total Reward: -63.65043089295566, Epsilon: 0.05, Y(0): 14.83
# Episode 84, Total Reward: -47.95574835985512, Epsilon: 0.05, Y(0): 15.98
# Episode 85, Total Reward: 8.015747831630597, Epsilon: 0.05, Y(0): 22.46
# Episode 86, Total Reward: -64.89316943756569, Epsilon: 0.05, Y(0): nan
# Episode 87, Total Reward: -62.875444039356424, Epsilon: 0.05, Y(0): nan
# Episode 88, Total Reward: -63.096422339838085, Epsilon: 0.05, Y(0): nan
# Episode 89, Total Reward: -26.61723972320502, Epsilon: 0.05, Y(0): nan
# Episode 90, Total Reward: -49.06456476705956, Epsilon: 0.05, Y(0): 17.89
# Episode 91, Total Reward: -32.25727413702919, Epsilon: 0.05, Y(0): nan
# Episode 92, Total Reward: -66.10098385604527, Epsilon: 0.05, Y(0): 11.20
# Episode 93, Total Reward: -12.964075159322732, Epsilon: 0.05, Y(0): nan
# Episode 94, Total Reward: -4.5579700819670705, Epsilon: 0.05, Y(0): 23.44
# Episode 95, Total Reward: -50.27463782512142, Epsilon: 0.05, Y(0): nan
# Episode 96, Total Reward: -72.43942943892738, Epsilon: 0.05, Y(0): nan
# Episode 97, Total Reward: -38.58545071961172, Epsilon: 0.05, Y(0): nan
# Episode 98, Total Reward: -47.92002103720822, Epsilon: 0.05, Y(0): nan
# Episode 99, Total Reward: -24.083487741256434, Epsilon: 0.05, Y(0): nan
# Episode 100, Total Reward: -65.21883784591452, Epsilon: 0.05, Y(0): 15.15
# Episode 101, Total Reward: -45.676022624008176, Epsilon: 0.05, Y(0): nan
# Episode 102, Total Reward: 17.87808779660174, Epsilon: 0.05, Y(0): nan
# Episode 103, Total Reward: -40.37643550922999, Epsilon: 0.05, Y(0): nan
# Episode 104, Total Reward: -51.60645871930989, Epsilon: 0.05, Y(0): 20.21
# Episode 105, Total Reward: -35.03592145619422, Epsilon: 0.05, Y(0): 17.60
# Episode 106, Total Reward: -10.013659574425901, Epsilon: 0.05, Y(0): 23.35
# Episode 107, Total Reward: -51.25221286070967, Epsilon: 0.05, Y(0): 17.13
# Episode 108, Total Reward: 23.733456076715775, Epsilon: 0.05, Y(0): 26.00
# Episode 109, Total Reward: -25.35812132934947, Epsilon: 0.05, Y(0): 20.01
# Episode 110, Total Reward: -48.434835915930705, Epsilon: 0.05, Y(0): nan
# Episode 111, Total Reward: -56.92014489957434, Epsilon: 0.05, Y(0): nan
# Episode 112, Total Reward: -49.720876899201265, Epsilon: 0.05, Y(0): 16.11
# Episode 113, Total Reward: -43.70693790891898, Epsilon: 0.05, Y(0): 17.25
# Episode 114, Total Reward: -31.785191774578706, Epsilon: 0.05, Y(0): 20.92
# Episode 115, Total Reward: -51.74849508280958, Epsilon: 0.05, Y(0): 20.85
# Episode 116, Total Reward: -53.10331955435562, Epsilon: 0.05, Y(0): nan
# Episode 117, Total Reward: -39.74940692007851, Epsilon: 0.05, Y(0): 21.51
# Episode 118, Total Reward: -63.527662356578666, Epsilon: 0.05, Y(0): 16.55
# Episode 119, Total Reward: -58.558790446627576, Epsilon: 0.05, Y(0): nan
# Episode 120, Total Reward: -50.82822575095954, Epsilon: 0.05, Y(0): 19.85
# Episode 121, Total Reward: -12.5575077366081, Epsilon: 0.05, Y(0): nan
# Episode 122, Total Reward: -33.5802785815914, Epsilon: 0.05, Y(0): 22.76
# Episode 123, Total Reward: -16.000380464051887, Epsilon: 0.05, Y(0): 23.23
# Episode 124, Total Reward: -30.108632675659223, Epsilon: 0.05, Y(0): nan
# Episode 125, Total Reward: -68.8927847300349, Epsilon: 0.05, Y(0): nan
# Episode 126, Total Reward: -52.079257169382096, Epsilon: 0.05, Y(0): 17.99
# Episode 127, Total Reward: -61.21785108169132, Epsilon: 0.05, Y(0): 19.85
# Episode 128, Total Reward: -36.008284690966654, Epsilon: 0.05, Y(0): 22.32
# Episode 129, Total Reward: -43.39893335528767, Epsilon: 0.05, Y(0): 24.53
# Episode 130, Total Reward: -49.49416150152532, Epsilon: 0.05, Y(0): nan
# Episode 131, Total Reward: -64.87875119601338, Epsilon: 0.05, Y(0): 16.73
# Episode 132, Total Reward: -40.02176171819946, Epsilon: 0.05, Y(0): 21.70
# Episode 133, Total Reward: -49.35948394771382, Epsilon: 0.05, Y(0): 19.83
# Episode 134, Total Reward: -43.977955803172044, Epsilon: 0.05, Y(0): nan
# Episode 135, Total Reward: -61.72781177422356, Epsilon: 0.05, Y(0): nan
# Episode 136, Total Reward: -57.6529302987534, Epsilon: 0.05, Y(0): nan
# Episode 137, Total Reward: -46.18566948334357, Epsilon: 0.05, Y(0): 19.40
# Episode 138, Total Reward: -48.64428347476434, Epsilon: 0.05, Y(0): nan
# Episode 139, Total Reward: -44.07290420736844, Epsilon: 0.05, Y(0): 21.91
# Episode 140, Total Reward: -58.93186074554269, Epsilon: 0.05, Y(0): 17.29
# Episode 141, Total Reward: -44.37710832342541, Epsilon: 0.05, Y(0): 23.70
# Episode 142, Total Reward: -49.856714148349155, Epsilon: 0.05, Y(0): 21.16
# Episode 143, Total Reward: -18.799171497545426, Epsilon: 0.05, Y(0): 23.01
# Episode 144, Total Reward: -55.837268276629956, Epsilon: 0.05, Y(0): nan
# Episode 145, Total Reward: -39.22297174254355, Epsilon: 0.05, Y(0): 19.39
# Episode 146, Total Reward: -3.934076455018169, Epsilon: 0.05, Y(0): 23.91
# Episode 147, Total Reward: -52.209877984341276, Epsilon: 0.05, Y(0): 16.53
# Episode 148, Total Reward: -50.785769428199046, Epsilon: 0.05, Y(0): 18.11
# Episode 149, Total Reward: -29.133938977753864, Epsilon: 0.05, Y(0): 20.65
# Episode 150, Total Reward: -54.36135597352807, Epsilon: 0.05, Y(0): 22.11
# Episode 151, Total Reward: -55.061384309124, Epsilon: 0.05, Y(0): 17.72
# Episode 152, Total Reward: -40.30150400300737, Epsilon: 0.05, Y(0): 20.82
# Episode 153, Total Reward: -31.813608107310138, Epsilon: 0.05, Y(0): 21.16
# Episode 154, Total Reward: -49.12911999184801, Epsilon: 0.05, Y(0): nan
# Episode 155, Total Reward: -25.936438172918344, Epsilon: 0.05, Y(0): nan
# Episode 156, Total Reward: -33.63602375056664, Epsilon: 0.05, Y(0): nan
# Episode 157, Total Reward: -35.48033043333238, Epsilon: 0.05, Y(0): 19.19
# Episode 158, Total Reward: -50.47842382970919, Epsilon: 0.05, Y(0): 16.66
# Episode 159, Total Reward: -38.61051144779505, Epsilon: 0.05, Y(0): nan
# Episode 160, Total Reward: -20.308936677330372, Epsilon: 0.05, Y(0): 22.08
# Episode 161, Total Reward: -53.77973925964019, Epsilon: 0.05, Y(0): nan
# Episode 162, Total Reward: -63.46256564490724, Epsilon: 0.05, Y(0): 17.21
# Episode 163, Total Reward: -59.578818056067654, Epsilon: 0.05, Y(0): 20.95
# Episode 164, Total Reward: -43.08867618416949, Epsilon: 0.05, Y(0): 23.14
# Episode 165, Total Reward: -12.119182834128473, Epsilon: 0.05, Y(0): 22.77
# Episode 166, Total Reward: -39.37488942561114, Epsilon: 0.05, Y(0): 19.97
# Episode 167, Total Reward: -43.48632051306749, Epsilon: 0.05, Y(0): 23.38
# Episode 168, Total Reward: -31.475939814543864, Epsilon: 0.05, Y(0): nan
# Episode 169, Total Reward: -45.00393193630627, Epsilon: 0.05, Y(0): 16.46
# Episode 170, Total Reward: -56.948066717653184, Epsilon: 0.05, Y(0): 19.29
# Episode 171, Total Reward: -34.64837363817888, Epsilon: 0.05, Y(0): 21.74
# Episode 172, Total Reward: -31.20734399391262, Epsilon: 0.05, Y(0): 19.69
# Episode 173, Total Reward: 11.184811633911753, Epsilon: 0.05, Y(0): 24.34
# Episode 174, Total Reward: -35.67137536654682, Epsilon: 0.05, Y(0): 20.96
# Episode 175, Total Reward: -55.306144008093234, Epsilon: 0.05, Y(0): 19.04
# Episode 176, Total Reward: -50.760752549538516, Epsilon: 0.05, Y(0): 17.75
# Episode 177, Total Reward: -49.196257371666256, Epsilon: 0.05, Y(0): 17.02
# Episode 178, Total Reward: -39.269914411675174, Epsilon: 0.05, Y(0): 19.02
# Episode 179, Total Reward: -48.87142937744282, Epsilon: 0.05, Y(0): 19.10
# Episode 180, Total Reward: -44.82251832719904, Epsilon: 0.05, Y(0): 16.88
# Episode 181, Total Reward: -57.59337752496446, Epsilon: 0.05, Y(0): 19.25
# Episode 182, Total Reward: -47.326661588386585, Epsilon: 0.05, Y(0): nan
# Episode 183, Total Reward: -18.375245130906457, Epsilon: 0.05, Y(0): 23.76
# Episode 184, Total Reward: -12.297698019066601, Epsilon: 0.05, Y(0): nan
# Episode 185, Total Reward: -50.33015849438996, Epsilon: 0.05, Y(0): 15.50
# Episode 186, Total Reward: -39.33971488897185, Epsilon: 0.05, Y(0): 19.83
# Episode 187, Total Reward: -52.350079969496235, Epsilon: 0.05, Y(0): 16.08
# Episode 188, Total Reward: -40.48853934030689, Epsilon: 0.05, Y(0): 19.78
# Episode 189, Total Reward: -54.23066704998888, Epsilon: 0.05, Y(0): 19.09
# Episode 190, Total Reward: -30.944907488613616, Epsilon: 0.05, Y(0): 20.03
# Episode 191, Total Reward: -37.17136764800633, Epsilon: 0.05, Y(0): 17.91
# Episode 192, Total Reward: 18.179717752298345, Epsilon: 0.05, Y(0): 27.03
# Episode 193, Total Reward: -50.04496665144718, Epsilon: 0.05, Y(0): 17.34
# Episode 194, Total Reward: -18.430978929463937, Epsilon: 0.05, Y(0): 23.55
# Episode 195, Total Reward: -32.73094329193146, Epsilon: 0.05, Y(0): 21.06
# Episode 196, Total Reward: -39.13553685810339, Epsilon: 0.05, Y(0): 19.58
# Episode 197, Total Reward: -1.5757771092112818, Epsilon: 0.05, Y(0): 23.64
# Episode 198, Total Reward: 5.426149800209388, Epsilon: 0.05, Y(0): 26.95
# Episode 199, Total Reward: -59.64919406707103, Epsilon: 0.05, Y(0): 16.01
# Episode 200, Total Reward: -35.737225141981106, Epsilon: 0.05, Y(0): 20.10
# Episode 201, Total Reward: -41.40340099482367, Epsilon: 0.05, Y(0): nan
# Episode 202, Total Reward: 0.36420589354987154, Epsilon: 0.05, Y(0): 24.66
# Episode 203, Total Reward: -48.62008525389399, Epsilon: 0.05, Y(0): nan
# Episode 204, Total Reward: -61.83023718605322, Epsilon: 0.05, Y(0): nan
# Episode 205, Total Reward: -38.210750889875136, Epsilon: 0.05, Y(0): 20.20
# Episode 206, Total Reward: -48.438038557906694, Epsilon: 0.05, Y(0): 18.37
# Episode 207, Total Reward: -55.61629765476038, Epsilon: 0.05, Y(0): 16.80
# Episode 208, Total Reward: -49.66993811660696, Epsilon: 0.05, Y(0): nan
# Episode 209, Total Reward: -44.28328073929623, Epsilon: 0.05, Y(0): 18.08
# Episode 210, Total Reward: -53.73656783991079, Epsilon: 0.05, Y(0): 18.39
# Episode 211, Total Reward: -56.92737026657086, Epsilon: 0.05, Y(0): nan
# Episode 212, Total Reward: -51.1546528742101, Epsilon: 0.05, Y(0): 18.37
# Episode 213, Total Reward: -44.21674400687887, Epsilon: 0.05, Y(0): nan
# Episode 214, Total Reward: -37.82486495569641, Epsilon: 0.05, Y(0): nan
# Episode 215, Total Reward: -52.78174388088733, Epsilon: 0.05, Y(0): 16.28
# Episode 216, Total Reward: -45.440450300391845, Epsilon: 0.05, Y(0): 15.79
# Episode 217, Total Reward: 12.305966134979183, Epsilon: 0.05, Y(0): nan
# Episode 218, Total Reward: 3.6973305619568837, Epsilon: 0.05, Y(0): 21.84
# Episode 219, Total Reward: -33.18684006136104, Epsilon: 0.05, Y(0): 19.57
# Episode 220, Total Reward: -36.608174981383954, Epsilon: 0.05, Y(0): nan
# Episode 221, Total Reward: -39.666024295455166, Epsilon: 0.05, Y(0): 20.18
# Episode 222, Total Reward: -41.12417587493713, Epsilon: 0.05, Y(0): 16.16
# Episode 223, Total Reward: -23.83763963351407, Epsilon: 0.05, Y(0): nan
# Episode 224, Total Reward: -41.23830050936105, Epsilon: 0.05, Y(0): 16.69
# Episode 225, Total Reward: -43.82325840723688, Epsilon: 0.05, Y(0): 17.42
# Episode 226, Total Reward: 2.0812343696428184, Epsilon: 0.05, Y(0): 20.62
# Episode 227, Total Reward: -42.87660622766103, Epsilon: 0.05, Y(0): 19.75
# Episode 228, Total Reward: -12.575532832410463, Epsilon: 0.05, Y(0): 20.78
# Episode 229, Total Reward: -54.64308400240865, Epsilon: 0.05, Y(0): 15.48
# Episode 230, Total Reward: -0.2607629515757388, Epsilon: 0.05, Y(0): 23.35
# Episode 231, Total Reward: -48.44434716992914, Epsilon: 0.05, Y(0): 18.64
# Episode 232, Total Reward: -35.70627210001356, Epsilon: 0.05, Y(0): 20.39
# Episode 233, Total Reward: -47.275209073209226, Epsilon: 0.05, Y(0): 17.33
# Episode 234, Total Reward: -59.673880145511966, Epsilon: 0.05, Y(0): 18.25
# Episode 235, Total Reward: -47.943691550652886, Epsilon: 0.05, Y(0): 20.68
# Episode 236, Total Reward: -29.945595603506778, Epsilon: 0.05, Y(0): 19.27
# Episode 237, Total Reward: -50.17863532821469, Epsilon: 0.05, Y(0): nan
# Episode 238, Total Reward: 69.86946101108546, Epsilon: 0.05, Y(0): 28.92
# Episode 239, Total Reward: -69.74543261718561, Epsilon: 0.05, Y(0): nan
# Episode 240, Total Reward: -51.228281587822295, Epsilon: 0.05, Y(0): 15.45
# Episode 241, Total Reward: -37.78827373119923, Epsilon: 0.05, Y(0): 19.64
# Episode 242, Total Reward: -40.82532961830255, Epsilon: 0.05, Y(0): 17.15
# Episode 243, Total Reward: -41.21083331082771, Epsilon: 0.05, Y(0): 15.94
# Episode 244, Total Reward: -59.75079935897656, Epsilon: 0.05, Y(0): 14.88
# Episode 245, Total Reward: -42.71524884967656, Epsilon: 0.05, Y(0): 12.25
# Episode 246, Total Reward: -12.89737851659939, Epsilon: 0.05, Y(0): 16.72
# Episode 247, Total Reward: -10.568407660077852, Epsilon: 0.05, Y(0): 16.01
# Episode 248, Total Reward: -71.54688111057263, Epsilon: 0.05, Y(0): 16.03
# Episode 249, Total Reward: -17.19005773221111, Epsilon: 0.05, Y(0): nan
# Episode 250, Total Reward: -49.08112769482828, Epsilon: 0.05, Y(0): 15.09
# Episode 251, Total Reward: -51.765193823518565, Epsilon: 0.05, Y(0): 13.45
# Episode 252, Total Reward: -11.02235786173779, Epsilon: 0.05, Y(0): 26.71
# Episode 253, Total Reward: 6.798847799633574, Epsilon: 0.05, Y(0): 20.10
# Episode 254, Total Reward: 50.27763135682356, Epsilon: 0.05, Y(0): 26.17
# Episode 255, Total Reward: -64.07211739674213, Epsilon: 0.05, Y(0): 19.43
# Episode 256, Total Reward: -52.78893454662162, Epsilon: 0.05, Y(0): 10.33
# Episode 257, Total Reward: -35.814982614710694, Epsilon: 0.05, Y(0): 18.38
# Episode 258, Total Reward: -30.29210469818583, Epsilon: 0.05, Y(0): 17.66
# Episode 259, Total Reward: -87.34688181500474, Epsilon: 0.05, Y(0): 12.48
# Episode 260, Total Reward: -51.67232957415221, Epsilon: 0.05, Y(0): 18.02
# Episode 261, Total Reward: -54.50327445110986, Epsilon: 0.05, Y(0): 13.74
# Episode 262, Total Reward: -34.257315268789846, Epsilon: 0.05, Y(0): 19.79
# Episode 263, Total Reward: -45.09546791617756, Epsilon: 0.05, Y(0): 14.69
# Episode 264, Total Reward: -54.14916531476907, Epsilon: 0.05, Y(0): nan
# Episode 265, Total Reward: -60.200687884779484, Epsilon: 0.05, Y(0): 13.88
# Episode 266, Total Reward: -60.97842654584723, Epsilon: 0.05, Y(0): 10.82
# Episode 267, Total Reward: -43.318280765297494, Epsilon: 0.05, Y(0): 16.53
# Episode 268, Total Reward: -37.89802002930924, Epsilon: 0.05, Y(0): 11.13
# Episode 269, Total Reward: -70.27917036772963, Epsilon: 0.05, Y(0): 19.26
# Episode 270, Total Reward: -52.596653572208844, Epsilon: 0.05, Y(0): 17.46
# Episode 271, Total Reward: -65.98611381020517, Epsilon: 0.05, Y(0): 13.67
# Episode 272, Total Reward: -32.699666056695555, Epsilon: 0.05, Y(0): 15.38
# Episode 273, Total Reward: -54.23295994841692, Epsilon: 0.05, Y(0): 11.66
# Episode 274, Total Reward: -65.98428277328941, Epsilon: 0.05, Y(0): 15.15
# Episode 275, Total Reward: -47.04040924532774, Epsilon: 0.05, Y(0): 13.16
# Episode 276, Total Reward: 2.7671436947138117, Epsilon: 0.05, Y(0): 19.90
# Episode 277, Total Reward: 25.374562848247926, Epsilon: 0.05, Y(0): 25.54
# Episode 278, Total Reward: -14.610308285018709, Epsilon: 0.05, Y(0): 16.93
# Episode 279, Total Reward: -21.302559539322868, Epsilon: 0.05, Y(0): 23.31
# Episode 280, Total Reward: -15.467100686815208, Epsilon: 0.05, Y(0): 19.48
# Episode 281, Total Reward: -29.732752112762974, Epsilon: 0.05, Y(0): 18.73
# Episode 282, Total Reward: -37.249839325934964, Epsilon: 0.05, Y(0): 18.60
# Episode 283, Total Reward: -55.51220157747947, Epsilon: 0.05, Y(0): 14.66
# Episode 284, Total Reward: -48.55921969280311, Epsilon: 0.05, Y(0): 15.90
# Episode 285, Total Reward: -19.452867866528564, Epsilon: 0.05, Y(0): 18.58
# Episode 286, Total Reward: -59.64774532216997, Epsilon: 0.05, Y(0): 11.65
# Episode 287, Total Reward: 6.810982644613232, Epsilon: 0.05, Y(0): 24.81
# Episode 288, Total Reward: -45.54557196126496, Epsilon: 0.05, Y(0): 10.11
# Episode 289, Total Reward: -46.5180559329268, Epsilon: 0.05, Y(0): 14.00
# Episode 290, Total Reward: -55.730271690200176, Epsilon: 0.05, Y(0): 17.44
# Episode 291, Total Reward: -11.447453058431769, Epsilon: 0.05, Y(0): 14.35
# Episode 292, Total Reward: -6.726921024939075, Epsilon: 0.05, Y(0): 17.81
# Episode 293, Total Reward: -42.59892999442427, Epsilon: 0.05, Y(0): 15.41
# Episode 294, Total Reward: -20.693169503448146, Epsilon: 0.05, Y(0): 19.21
# Episode 295, Total Reward: -62.446884817194764, Epsilon: 0.05, Y(0): 16.93
# Episode 296, Total Reward: -41.31060042322418, Epsilon: 0.05, Y(0): 14.95
# Episode 297, Total Reward: -19.770217900608554, Epsilon: 0.05, Y(0): 14.94
# Episode 298, Total Reward: -11.998739926500228, Epsilon: 0.05, Y(0): 12.20
# Episode 299, Total Reward: -25.520787956450874, Epsilon: 0.05, Y(0): 15.83
# Episode 300, Total Reward: -53.58343375282741, Epsilon: 0.05, Y(0): 15.70
# Episode 301, Total Reward: -29.218258438008238, Epsilon: 0.05, Y(0): 17.78
# Episode 302, Total Reward: -31.074501160539317, Epsilon: 0.05, Y(0): 17.76
# Episode 303, Total Reward: -61.777845055991506, Epsilon: 0.05, Y(0): 16.14
# Episode 304, Total Reward: 5.608450466269589, Epsilon: 0.05, Y(0): 18.53
# Episode 305, Total Reward: -18.48477236402681, Epsilon: 0.05, Y(0): 18.17
# Episode 306, Total Reward: -59.943187647447985, Epsilon: 0.05, Y(0): 11.22
# Episode 307, Total Reward: -55.464961170551355, Epsilon: 0.05, Y(0): 15.32
# Episode 308, Total Reward: -32.608018069637446, Epsilon: 0.05, Y(0): 13.65
# Episode 309, Total Reward: -33.15669175217299, Epsilon: 0.05, Y(0): 11.70
# Episode 310, Total Reward: -26.044427900857386, Epsilon: 0.05, Y(0): 26.24
# Episode 311, Total Reward: -49.477372559881125, Epsilon: 0.05, Y(0): 26.01
# Episode 312, Total Reward: -46.60949900810727, Epsilon: 0.05, Y(0): 25.59
# Episode 313, Total Reward: -48.04372012626236, Epsilon: 0.05, Y(0): 16.34
# Episode 314, Total Reward: -21.580594139196677, Epsilon: 0.05, Y(0): nan
# Episode 315, Total Reward: -53.08642405956064, Epsilon: 0.05, Y(0): 18.38
# Episode 316, Total Reward: -60.91366495007867, Epsilon: 0.05, Y(0): 21.32
# Episode 317, Total Reward: -53.18693195771779, Epsilon: 0.05, Y(0): 12.29
# Episode 318, Total Reward: -30.64550041433693, Epsilon: 0.05, Y(0): 22.16
# Episode 319, Total Reward: -45.08001043170945, Epsilon: 0.05, Y(0): 19.15
# Episode 320, Total Reward: -27.920445734582227, Epsilon: 0.05, Y(0): 24.77
# Episode 321, Total Reward: -54.28265604707557, Epsilon: 0.05, Y(0): nan
# Episode 322, Total Reward: -38.61658455526744, Epsilon: 0.05, Y(0): 17.93
# Episode 323, Total Reward: -20.660769075798555, Epsilon: 0.05, Y(0): 35.17
# Episode 324, Total Reward: -42.62207785338508, Epsilon: 0.05, Y(0): nan
# Episode 325, Total Reward: -44.2433725509886, Epsilon: 0.05, Y(0): 16.43
# Episode 326, Total Reward: -9.38201982939993, Epsilon: 0.05, Y(0): nan
# Episode 327, Total Reward: -67.02464012604398, Epsilon: 0.05, Y(0): 19.23
# Episode 328, Total Reward: -54.59852049780548, Epsilon: 0.05, Y(0): 17.20
# Episode 329, Total Reward: -58.5771306764627, Epsilon: 0.05, Y(0): 20.70
# Episode 330, Total Reward: -53.634876703108674, Epsilon: 0.05, Y(0): 19.07
# Episode 331, Total Reward: -39.01112384705011, Epsilon: 0.05, Y(0): nan
# Episode 332, Total Reward: -38.629433364153776, Epsilon: 0.05, Y(0): 12.42
# Episode 333, Total Reward: -49.74119564657449, Epsilon: 0.05, Y(0): nan
# Episode 334, Total Reward: -37.0138862672607, Epsilon: 0.05, Y(0): nan
# Episode 335, Total Reward: -72.59462712407559, Epsilon: 0.05, Y(0): nan
# Episode 336, Total Reward: -5.406840690804869, Epsilon: 0.05, Y(0): 12.17
# Episode 337, Total Reward: -61.06910002616152, Epsilon: 0.05, Y(0): 15.65
# Episode 338, Total Reward: 8.120759268271073, Epsilon: 0.05, Y(0): 16.10
# Episode 339, Total Reward: -50.29827297148439, Epsilon: 0.05, Y(0): 18.83
# Episode 340, Total Reward: -58.43884449958038, Epsilon: 0.05, Y(0): 12.33
# Episode 341, Total Reward: -30.594152140962944, Epsilon: 0.05, Y(0): 6.30
# Episode 342, Total Reward: -13.068124364774054, Epsilon: 0.05, Y(0): 8.13
# Episode 343, Total Reward: -15.857530954686968, Epsilon: 0.05, Y(0): 25.18
# Episode 344, Total Reward: -21.16954500765243, Epsilon: 0.05, Y(0): 12.02
# Episode 345, Total Reward: -43.2358586277965, Epsilon: 0.05, Y(0): 7.06
# Episode 346, Total Reward: -13.27176937379464, Epsilon: 0.05, Y(0): 15.71
# Episode 347, Total Reward: -23.87544853462103, Epsilon: 0.05, Y(0): 8.99
# Episode 348, Total Reward: -33.94196922626645, Epsilon: 0.05, Y(0): 13.16
# Episode 349, Total Reward: -48.42428894139883, Epsilon: 0.05, Y(0): 5.61
# Episode 350, Total Reward: -22.2363496196798, Epsilon: 0.05, Y(0): 18.59
# Episode 351, Total Reward: -42.268804447609796, Epsilon: 0.05, Y(0): 19.88
# Episode 352, Total Reward: -36.65254324182856, Epsilon: 0.05, Y(0): nan
# Episode 353, Total Reward: -38.35231351558434, Epsilon: 0.05, Y(0): nan
# Episode 354, Total Reward: -58.419688638875186, Epsilon: 0.05, Y(0): nan
# Episode 355, Total Reward: -48.562944862509525, Epsilon: 0.05, Y(0): 16.95
# Episode 356, Total Reward: -34.52104105797073, Epsilon: 0.05, Y(0): 13.07
# Episode 357, Total Reward: -52.563393278930526, Epsilon: 0.05, Y(0): 9.71
# Episode 358, Total Reward: -56.06703958031873, Epsilon: 0.05, Y(0): 11.47
# Episode 359, Total Reward: -27.901780707355776, Epsilon: 0.05, Y(0): 14.15
# Episode 360, Total Reward: -48.12767339273727, Epsilon: 0.05, Y(0): 22.90
# Episode 361, Total Reward: -47.96070256613423, Epsilon: 0.05, Y(0): 24.71
# Episode 362, Total Reward: -7.574349550557698, Epsilon: 0.05, Y(0): 20.35
# Episode 363, Total Reward: -42.16843933978876, Epsilon: 0.05, Y(0): 20.43
# Episode 364, Total Reward: -27.634037590280236, Epsilon: 0.05, Y(0): 21.44
# Episode 365, Total Reward: -54.93564668088025, Epsilon: 0.05, Y(0): 25.62
# Episode 366, Total Reward: -24.32015540350509, Epsilon: 0.05, Y(0): nan
# Episode 367, Total Reward: -64.84840001028125, Epsilon: 0.05, Y(0): 13.04
# Episode 368, Total Reward: -72.7309279940096, Epsilon: 0.05, Y(0): 19.23
# Episode 369, Total Reward: -31.25755905275579, Epsilon: 0.05, Y(0): nan
# Episode 370, Total Reward: -33.971444094467024, Epsilon: 0.05, Y(0): 29.60
# Episode 371, Total Reward: -56.14108832179452, Epsilon: 0.05, Y(0): 19.24
# Episode 372, Total Reward: -70.80295004039547, Epsilon: 0.05, Y(0): 30.02
# Episode 373, Total Reward: -47.12006903755397, Epsilon: 0.05, Y(0): 26.97
# Episode 374, Total Reward: -24.396438315888112, Epsilon: 0.05, Y(0): 29.86
# Episode 375, Total Reward: -64.86656182286376, Epsilon: 0.05, Y(0): 18.08
# Episode 376, Total Reward: -49.10817943577406, Epsilon: 0.05, Y(0): 20.25
# Episode 377, Total Reward: -22.170647311684878, Epsilon: 0.05, Y(0): 15.68
# Episode 378, Total Reward: -4.137278500568464, Epsilon: 0.05, Y(0): 18.51
# Episode 379, Total Reward: -53.571747871923044, Epsilon: 0.05, Y(0): 17.92
# Episode 380, Total Reward: 5.726666177308124, Epsilon: 0.05, Y(0): 22.29
# Episode 381, Total Reward: -31.86075623088618, Epsilon: 0.05, Y(0): nan
# Episode 382, Total Reward: 3.3115575138988858, Epsilon: 0.05, Y(0): 21.64
# Episode 383, Total Reward: -24.248333120605736, Epsilon: 0.05, Y(0): 23.14
# Episode 384, Total Reward: -40.97684936425579, Epsilon: 0.05, Y(0): 11.56
# Episode 385, Total Reward: -62.961000870951885, Epsilon: 0.05, Y(0): 13.66
# Episode 386, Total Reward: 14.123152147174608, Epsilon: 0.05, Y(0): 16.50
# Episode 387, Total Reward: -67.27703697378665, Epsilon: 0.05, Y(0): 6.05
# Episode 388, Total Reward: -70.02978813166267, Epsilon: 0.05, Y(0): 12.08
# Episode 389, Total Reward: -40.5360525024861, Epsilon: 0.05, Y(0): 13.84
# Episode 390, Total Reward: -14.470650006065446, Epsilon: 0.05, Y(0): 11.16
# Episode 391, Total Reward: -28.18295656808989, Epsilon: 0.05, Y(0): 6.15
# Episode 392, Total Reward: -56.3955174607931, Epsilon: 0.05, Y(0): 5.43
# Episode 393, Total Reward: -41.626126659610996, Epsilon: 0.05, Y(0): 3.73
# Episode 394, Total Reward: -42.78756101794873, Epsilon: 0.05, Y(0): 5.30
# Episode 395, Total Reward: 68.08855741694144, Epsilon: 0.05, Y(0): 14.00
# Episode 396, Total Reward: 32.7770416062312, Epsilon: 0.05, Y(0): 11.27
# Episode 397, Total Reward: -57.06530123700743, Epsilon: 0.05, Y(0): nan
# Episode 398, Total Reward: 8.693397388576953, Epsilon: 0.05, Y(0): 10.29
# Episode 399, Total Reward: -26.451356886748197, Epsilon: 0.05, Y(0): 7.75
# Episode 400, Total Reward: -60.466092034044955, Epsilon: 0.05, Y(0): 8.03
# Episode 401, Total Reward: -38.24125493476721, Epsilon: 0.05, Y(0): 7.56
# Episode 402, Total Reward: -21.76470780564952, Epsilon: 0.05, Y(0): 8.58
# Episode 403, Total Reward: -62.05627993458136, Epsilon: 0.05, Y(0): 6.06
# Episode 404, Total Reward: -22.231971666471413, Epsilon: 0.05, Y(0): 9.46
# Episode 405, Total Reward: 25.55400610776681, Epsilon: 0.05, Y(0): 11.10
# Episode 406, Total Reward: 27.229645992162073, Epsilon: 0.05, Y(0): 15.41
# Episode 407, Total Reward: -49.81483840366608, Epsilon: 0.05, Y(0): 7.11
# Episode 408, Total Reward: -37.310742064489375, Epsilon: 0.05, Y(0): 8.09
# Episode 409, Total Reward: -48.55918371536124, Epsilon: 0.05, Y(0): 11.37
# Episode 410, Total Reward: -47.98131759483958, Epsilon: 0.05, Y(0): 5.98
# Episode 411, Total Reward: -18.179491545494894, Epsilon: 0.05, Y(0): 3.11
# Episode 412, Total Reward: -7.795690146145212, Epsilon: 0.05, Y(0): 6.05
# Episode 413, Total Reward: -56.94489658216118, Epsilon: 0.05, Y(0): 4.25
# Episode 414, Total Reward: -48.604547114750986, Epsilon: 0.05, Y(0): 4.39
# Episode 415, Total Reward: -21.04515199100107, Epsilon: 0.05, Y(0): 9.44
# Episode 416, Total Reward: -39.314166726367596, Epsilon: 0.05, Y(0): 4.87
# Episode 417, Total Reward: -22.054869797551206, Epsilon: 0.05, Y(0): 6.55
# Episode 418, Total Reward: -31.675554190076816, Epsilon: 0.05, Y(0): 2.15
# Episode 419, Total Reward: -23.1445531156491, Epsilon: 0.05, Y(0): 5.23
# Episode 420, Total Reward: -65.67335076825805, Epsilon: 0.05, Y(0): 4.78
# Episode 421, Total Reward: -51.78563508372014, Epsilon: 0.05, Y(0): 4.01
# Episode 422, Total Reward: 26.878554025708887, Epsilon: 0.05, Y(0): 5.22
# Episode 423, Total Reward: -60.002630305657526, Epsilon: 0.05, Y(0): 2.94
# Episode 424, Total Reward: -63.91948981640419, Epsilon: 0.05, Y(0): 4.03
# Episode 425, Total Reward: -51.957380196437455, Epsilon: 0.05, Y(0): 3.46
# Episode 426, Total Reward: -52.55020663648625, Epsilon: 0.05, Y(0): 3.42
# Episode 427, Total Reward: -59.29153300692828, Epsilon: 0.05, Y(0): 2.89
# Episode 428, Total Reward: -63.78774542608627, Epsilon: 0.05, Y(0): 2.17
# Episode 429, Total Reward: -8.03985582134299, Epsilon: 0.05, Y(0): 4.34
# Episode 430, Total Reward: -27.300716978479187, Epsilon: 0.05, Y(0): 2.87
# Episode 431, Total Reward: -26.83235084012395, Epsilon: 0.05, Y(0): 2.75
# Episode 432, Total Reward: -58.75964589719886, Epsilon: 0.05, Y(0): 2.85
# Episode 433, Total Reward: -51.39836991364903, Epsilon: 0.05, Y(0): 2.88
# Episode 434, Total Reward: -51.867145373324774, Epsilon: 0.05, Y(0): 2.95
# Episode 435, Total Reward: -19.976024639327363, Epsilon: 0.05, Y(0): 3.42
# Episode 436, Total Reward: -60.22815478067788, Epsilon: 0.05, Y(0): 2.43
# Episode 437, Total Reward: -23.28247862294049, Epsilon: 0.05, Y(0): 2.50
# Episode 438, Total Reward: -26.457966558794368, Epsilon: 0.05, Y(0): nan
# Episode 439, Total Reward: -53.964280219624435, Epsilon: 0.05, Y(0): nan
# Episode 440, Total Reward: -42.106938393001734, Epsilon: 0.05, Y(0): 2.16
# Episode 441, Total Reward: -37.07520452635098, Epsilon: 0.05, Y(0): 2.63
# Episode 442, Total Reward: -56.67910293098445, Epsilon: 0.05, Y(0): 1.45
# Episode 443, Total Reward: -54.77876271437113, Epsilon: 0.05, Y(0): 1.84
# Episode 444, Total Reward: -32.3735615766605, Epsilon: 0.05, Y(0): 1.97
# Episode 445, Total Reward: -47.14960524135365, Epsilon: 0.05, Y(0): 1.51
# Episode 446, Total Reward: -31.694169580688545, Epsilon: 0.05, Y(0): 1.52
# Episode 447, Total Reward: -1.2967744272824033, Epsilon: 0.05, Y(0): 1.55
# Episode 448, Total Reward: -39.82172105811744, Epsilon: 0.05, Y(0): 1.52
# Episode 449, Total Reward: -39.1108339506388, Epsilon: 0.05, Y(0): nan
# Episode 450, Total Reward: -43.9586119920313, Epsilon: 0.05, Y(0): 1.24
# Episode 451, Total Reward: -69.86242801363024, Epsilon: 0.05, Y(0): 1.09
# Episode 452, Total Reward: -64.51992721454256, Epsilon: 0.05, Y(0): 0.97
# Episode 453, Total Reward: -61.853968853359184, Epsilon: 0.05, Y(0): 0.92
# Episode 454, Total Reward: -54.65637363722275, Epsilon: 0.05, Y(0): 1.01
# Episode 455, Total Reward: -39.43722742486773, Epsilon: 0.05, Y(0): 0.90
# Episode 456, Total Reward: -51.29034892998198, Epsilon: 0.05, Y(0): 0.90
# Episode 457, Total Reward: -67.48944707716655, Epsilon: 0.05, Y(0): 0.89
# Episode 458, Total Reward: -61.498576558460876, Epsilon: 0.05, Y(0): 0.93
# Episode 459, Total Reward: 43.70544842933826, Epsilon: 0.05, Y(0): 0.87
# Episode 460, Total Reward: -45.267582207625814, Epsilon: 0.05, Y(0): 0.86
# Episode 461, Total Reward: -30.063290237622507, Epsilon: 0.05, Y(0): 0.96
# Episode 462, Total Reward: -52.54787661507929, Epsilon: 0.05, Y(0): 0.96
# Episode 463, Total Reward: -49.343126020870294, Epsilon: 0.05, Y(0): 0.90
# Episode 464, Total Reward: -4.802741652557247, Epsilon: 0.05, Y(0): 1.23
# Episode 465, Total Reward: -64.62975842336941, Epsilon: 0.05, Y(0): 1.25
# Episode 466, Total Reward: -6.1210473119293605, Epsilon: 0.05, Y(0): 1.19
# Episode 467, Total Reward: -25.865468082543305, Epsilon: 0.05, Y(0): 1.14
# Episode 468, Total Reward: -33.78260112985722, Epsilon: 0.05, Y(0): 1.06
# Episode 469, Total Reward: -49.3943730435262, Epsilon: 0.05, Y(0): 1.06
# Episode 470, Total Reward: -48.96843960068754, Epsilon: 0.05, Y(0): 0.95
# Episode 471, Total Reward: -35.953439136407, Epsilon: 0.05, Y(0): 0.88
# Episode 472, Total Reward: -35.5053645019425, Epsilon: 0.05, Y(0): 0.79
# Episode 473, Total Reward: -39.08765753997812, Epsilon: 0.05, Y(0): 0.84
# Episode 474, Total Reward: -36.35657737934077, Epsilon: 0.05, Y(0): nan
# Episode 475, Total Reward: -64.84985256379919, Epsilon: 0.05, Y(0): 1.07
# Episode 476, Total Reward: -40.65452743953886, Epsilon: 0.05, Y(0): 1.01
# Episode 477, Total Reward: -21.673614084370314, Epsilon: 0.05, Y(0): 1.03
# Episode 478, Total Reward: -41.84166856500855, Epsilon: 0.05, Y(0): 1.15
# Episode 479, Total Reward: -60.625878235000776, Epsilon: 0.05, Y(0): 1.20
# Episode 480, Total Reward: -47.930167272985464, Epsilon: 0.05, Y(0): 1.27
# Episode 481, Total Reward: -35.009973023254965, Epsilon: 0.05, Y(0): 1.27
# Episode 482, Total Reward: -68.5892519368998, Epsilon: 0.05, Y(0): 1.35
# Episode 483, Total Reward: -43.36127499956771, Epsilon: 0.05, Y(0): 1.37
# Episode 484, Total Reward: -36.87241278663342, Epsilon: 0.05, Y(0): 1.35
# Episode 485, Total Reward: -29.04894152018891, Epsilon: 0.05, Y(0): 1.30
# Episode 486, Total Reward: -64.40163017303134, Epsilon: 0.05, Y(0): 0.63
# Episode 487, Total Reward: -44.58914825768609, Epsilon: 0.05, Y(0): 1.16
# Episode 488, Total Reward: -33.27761795498014, Epsilon: 0.05, Y(0): 1.22
# Episode 489, Total Reward: -59.00849169373688, Epsilon: 0.05, Y(0): nan
# Episode 490, Total Reward: -50.748104126980856, Epsilon: 0.05, Y(0): 1.22
# Episode 491, Total Reward: 35.04684401527334, Epsilon: 0.05, Y(0): 1.05
# Episode 492, Total Reward: -54.06085533710547, Epsilon: 0.05, Y(0): 1.20
# Episode 493, Total Reward: -59.5071054952622, Epsilon: 0.05, Y(0): 1.17
# Episode 494, Total Reward: -47.18074661710134, Epsilon: 0.05, Y(0): 1.27
# Episode 495, Total Reward: -70.45794741909323, Epsilon: 0.05, Y(0): 1.31
# Episode 496, Total Reward: -23.841775690639544, Epsilon: 0.05, Y(0): 1.30
# Episode 497, Total Reward: 14.532483756743623, Epsilon: 0.05, Y(0): 1.34
# Episode 498, Total Reward: -19.809249671518977, Epsilon: 0.05, Y(0): 1.36
# Episode 499, Total Reward: 18.774240554505578, Epsilon: 0.05, Y(0): 1.17
# Episode 500, Total Reward: -53.39237389588463, Epsilon: 0.05, Y(0): 0.96
# Episode 501, Total Reward: -73.72051629447031, Epsilon: 0.05, Y(0): 1.00
# Episode 502, Total Reward: -27.078709249179134, Epsilon: 0.05, Y(0): 0.89
# Episode 503, Total Reward: -58.798315564839534, Epsilon: 0.05, Y(0): 1.00
# Episode 504, Total Reward: -43.817160488247865, Epsilon: 0.05, Y(0): 0.94
# Episode 505, Total Reward: -42.50534852055589, Epsilon: 0.05, Y(0): 0.89
# Episode 506, Total Reward: -5.6521128036560535, Epsilon: 0.05, Y(0): nan
# Episode 507, Total Reward: -48.492987402385886, Epsilon: 0.05, Y(0): 0.89
# Episode 508, Total Reward: -51.70896016460143, Epsilon: 0.05, Y(0): 0.89
# Episode 509, Total Reward: -40.7055970394693, Epsilon: 0.05, Y(0): 0.90
# Episode 510, Total Reward: -41.41983124086027, Epsilon: 0.05, Y(0): 0.89
# Episode 511, Total Reward: -44.931270618690725, Epsilon: 0.05, Y(0): 0.89
# Episode 512, Total Reward: -38.87141177133779, Epsilon: 0.05, Y(0): 0.89
# Episode 513, Total Reward: -50.35331796627173, Epsilon: 0.05, Y(0): 0.93
# Episode 514, Total Reward: -73.59366412827788, Epsilon: 0.05, Y(0): nan
# Episode 515, Total Reward: -61.064915851394204, Epsilon: 0.05, Y(0): 0.93
# Episode 516, Total Reward: -22.557036520287436, Epsilon: 0.05, Y(0): 0.93
# Episode 517, Total Reward: -37.51252698775615, Epsilon: 0.05, Y(0): 0.92
# Episode 518, Total Reward: -33.1081351947906, Epsilon: 0.05, Y(0): 0.93
# Episode 519, Total Reward: -14.824677529200223, Epsilon: 0.05, Y(0): 0.91
# Episode 520, Total Reward: -55.394195962169, Epsilon: 0.05, Y(0): 1.00
# Episode 521, Total Reward: -47.74912493351256, Epsilon: 0.05, Y(0): 0.89
# Episode 522, Total Reward: -49.86090632243149, Epsilon: 0.05, Y(0): 0.89
# Episode 523, Total Reward: -10.57044774718571, Epsilon: 0.05, Y(0): 0.90
# Episode 524, Total Reward: -56.443736928137724, Epsilon: 0.05, Y(0): 1.00
# Episode 525, Total Reward: -6.103066110887125, Epsilon: 0.05, Y(0): 1.00
# Episode 526, Total Reward: -59.58913491249966, Epsilon: 0.05, Y(0): 1.03
# Episode 527, Total Reward: -46.44343368927515, Epsilon: 0.05, Y(0): 1.00
# Episode 528, Total Reward: -49.92644263817835, Epsilon: 0.05, Y(0): 0.99
# Episode 529, Total Reward: -52.07333041518364, Epsilon: 0.05, Y(0): 0.90
# Episode 530, Total Reward: -27.36143922774187, Epsilon: 0.05, Y(0): 0.89
# Episode 531, Total Reward: -53.74206481479346, Epsilon: 0.05, Y(0): 0.92
# Episode 532, Total Reward: -52.56756643491864, Epsilon: 0.05, Y(0): 0.95
# Episode 533, Total Reward: -58.14385877269038, Epsilon: 0.05, Y(0): 0.89
# Episode 534, Total Reward: 34.670449725766254, Epsilon: 0.05, Y(0): 0.90
# Episode 535, Total Reward: -50.41003865143672, Epsilon: 0.05, Y(0): 0.93
# Episode 536, Total Reward: 22.2872220318683, Epsilon: 0.05, Y(0): 0.88
# Episode 537, Total Reward: -63.66648323178547, Epsilon: 0.05, Y(0): nan
# Episode 538, Total Reward: -46.09741424096768, Epsilon: 0.05, Y(0): nan
# Episode 539, Total Reward: -21.291275730157476, Epsilon: 0.05, Y(0): 0.87
# Episode 540, Total Reward: -22.261015351681312, Epsilon: 0.05, Y(0): 0.97
# Episode 541, Total Reward: 20.59903046906835, Epsilon: 0.05, Y(0): 1.02
# Episode 542, Total Reward: -32.78779178016552, Epsilon: 0.05, Y(0): 0.97
# Episode 543, Total Reward: -39.42392938675895, Epsilon: 0.05, Y(0): 1.00
# Episode 544, Total Reward: -50.93693082892206, Epsilon: 0.05, Y(0): 0.93
# Episode 545, Total Reward: -54.149526506013174, Epsilon: 0.05, Y(0): 0.78
# Episode 546, Total Reward: -59.41018702474387, Epsilon: 0.05, Y(0): 0.94
# Episode 547, Total Reward: -49.007652110550936, Epsilon: 0.05, Y(0): 0.96
# Episode 548, Total Reward: 12.245255661790619, Epsilon: 0.05, Y(0): 1.03
# Episode 549, Total Reward: -33.88141875796555, Epsilon: 0.05, Y(0): 1.10
# Episode 550, Total Reward: -34.82238580913936, Epsilon: 0.05, Y(0): 1.11
# Episode 551, Total Reward: -88.38922081822813, Epsilon: 0.05, Y(0): 1.29
# Episode 552, Total Reward: -45.27380629883388, Epsilon: 0.05, Y(0): 1.13
# Episode 553, Total Reward: -53.51192588086406, Epsilon: 0.05, Y(0): 1.17
# Episode 554, Total Reward: -24.40516432403254, Epsilon: 0.05, Y(0): 1.03
# Episode 555, Total Reward: -39.53431411414693, Epsilon: 0.05, Y(0): 1.09
# Episode 556, Total Reward: -60.565040641937976, Epsilon: 0.05, Y(0): 1.05
# Episode 557, Total Reward: -55.61630971598182, Epsilon: 0.05, Y(0): 1.03
# Episode 558, Total Reward: -20.109352825438844, Epsilon: 0.05, Y(0): 1.05
# Episode 559, Total Reward: -6.904650412947134, Epsilon: 0.05, Y(0): 1.08
# Episode 560, Total Reward: 2.71059900240218, Epsilon: 0.05, Y(0): 0.95
# Episode 561, Total Reward: -36.25470286860849, Epsilon: 0.05, Y(0): 0.95
# Episode 562, Total Reward: -28.10604677543031, Epsilon: 0.05, Y(0): 1.00
# Episode 563, Total Reward: -16.062683404208734, Epsilon: 0.05, Y(0): 1.04
# Episode 564, Total Reward: -29.57973305129557, Epsilon: 0.05, Y(0): 0.97
# Episode 565, Total Reward: -61.99121173362579, Epsilon: 0.05, Y(0): 1.12
# Episode 566, Total Reward: -40.61934966111804, Epsilon: 0.05, Y(0): 0.97
# Episode 567, Total Reward: -52.02782628467689, Epsilon: 0.05, Y(0): 1.03
# Episode 568, Total Reward: -55.24392194804985, Epsilon: 0.05, Y(0): 0.99
# Episode 569, Total Reward: -21.258898856946182, Epsilon: 0.05, Y(0): 1.03
# Episode 570, Total Reward: -30.377264077618236, Epsilon: 0.05, Y(0): nan
# Episode 571, Total Reward: 8.019901690997271, Epsilon: 0.05, Y(0): 0.90
# Episode 572, Total Reward: -49.41237798321893, Epsilon: 0.05, Y(0): 0.93
# Episode 573, Total Reward: -73.66204702321826, Epsilon: 0.05, Y(0): 0.94
# Episode 574, Total Reward: -51.72955403670849, Epsilon: 0.05, Y(0): nan
# Episode 575, Total Reward: 6.95620750399462, Epsilon: 0.05, Y(0): 0.96
# Episode 576, Total Reward: -45.35997364519004, Epsilon: 0.05, Y(0): 1.14
# Episode 577, Total Reward: -46.38159376910112, Epsilon: 0.05, Y(0): nan
# Episode 578, Total Reward: -28.057118309333596, Epsilon: 0.05, Y(0): 1.00
# Episode 579, Total Reward: -28.900449523616434, Epsilon: 0.05, Y(0): 1.00
# Episode 580, Total Reward: 13.206500240387568, Epsilon: 0.05, Y(0): 0.97
# Episode 581, Total Reward: -21.5259794165797, Epsilon: 0.05, Y(0): 0.98
# Episode 582, Total Reward: -48.57536997728787, Epsilon: 0.05, Y(0): 0.72
# Episode 583, Total Reward: -53.18548679189442, Epsilon: 0.05, Y(0): 1.00
# Episode 584, Total Reward: -53.60858269624313, Epsilon: 0.05, Y(0): 0.98
# Episode 585, Total Reward: -59.210707858050384, Epsilon: 0.05, Y(0): 1.04
# Episode 586, Total Reward: -15.156978855176888, Epsilon: 0.05, Y(0): 1.01
# Episode 587, Total Reward: -59.670962504604134, Epsilon: 0.05, Y(0): 0.79
# Episode 588, Total Reward: -46.3263049401735, Epsilon: 0.05, Y(0): 0.99
# Episode 589, Total Reward: -44.33733066176868, Epsilon: 0.05, Y(0): 0.96
# Episode 590, Total Reward: -23.826819528323547, Epsilon: 0.05, Y(0): 0.88
# Episode 591, Total Reward: -39.207910785050935, Epsilon: 0.05, Y(0): nan
# Episode 592, Total Reward: -59.23382384035265, Epsilon: 0.05, Y(0): 1.25
# Episode 593, Total Reward: -38.01037446977395, Epsilon: 0.05, Y(0): 0.96
# Episode 594, Total Reward: -61.68133062800878, Epsilon: 0.05, Y(0): 1.00
# Episode 595, Total Reward: -42.97990453944828, Epsilon: 0.05, Y(0): 1.00
# Episode 596, Total Reward: -57.1829769683597, Epsilon: 0.05, Y(0): nan
# Episode 597, Total Reward: -45.229465106164916, Epsilon: 0.05, Y(0): 1.02
# Episode 598, Total Reward: -18.189441201761174, Epsilon: 0.05, Y(0): 0.97
# Episode 599, Total Reward: -26.131341264158028, Epsilon: 0.05, Y(0): 1.12

# %%
plt.plot(rewards)

# %%
plt.plot(fucntions)
